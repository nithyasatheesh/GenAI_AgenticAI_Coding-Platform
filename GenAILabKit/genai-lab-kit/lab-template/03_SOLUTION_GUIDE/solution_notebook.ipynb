# %% [markdown]
# # Guided Project: <LAB TITLE>
# ## Solution Notebook - trainer reference only

# %%
# Task 0 - Environment preflight
# %run ../scripts/setup_check.py

# %% [markdown]
# ## Task 1 - <title>

# %%
# full reference implementation

# %% [markdown]
# ## Task N - <title>

# %%
# full reference implementation

# %% [markdown]
# ## Validation
# Run `python ../scripts/validate_solution.py`.
