# %% [markdown]
# # Guided Project: <LAB TITLE>
# ## Participant Notebook
#
# ### Objective
# <one paragraph>
#
# ### Required pipeline
# <A -> B -> C -> ...>
#
# ### Ground rules
# - The VM is preconfigured. Do **not** run `pip install`.
# - Secrets are configured by the lab administrator.
# - Complete the `# TODO` cells in order.

# %%
# Task 0 - Environment preflight
# %run ../scripts/setup_check.py

# %% [markdown]
# ## Task 1 - <title>
#
# ### Goal
# <goal>
#
# ### Your tasks
# 1. ...
# 2. ...
#
# ### Hints
# - ...
#
# ### Expected result
# <what they should see>

# %%
# Task 1
# TODO

# %% [markdown]
# ## Task N - <title>
# ...

# %%
# Task N
# TODO

# %% [markdown]
# ## Final Validation Checklist
#
# - [ ] ...
# - [ ] ...
#
# Then run: `python ../scripts/validate_solution.py`
